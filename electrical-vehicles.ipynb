# %% [markdown]
# # **About Electrical Vehicles**

# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# For example, here's a helpful package to load

library(tidyverse) # metapackage of all tidyverse packages

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

list.files(path = "../input")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# [1] "electric-vechile-data-gov" "electric-vehicles-india"
# [3] "evpopulation"

# %%
Electric_Vehicle_Growth_1<- read.csv("../input/evpopulation/Electric_Vehicle_Population_Data (1).csv")

Electric_Vehicle_Growth_2<-read.csv("../input/evpopulation/Electric_Vehicle_Population_Data.csv")

Electric_Vehicle_Population<-read.csv("../input/electric-vehicles-india/EVIndia.csv")

Electric_Vehicle_Data_Gov<-read.csv("../input/electric-vechile-data-gov/Electric_Vehicle_Population_Data.csv")

# %%
head(Electric_Vehicle_Growth_1)
# Out:
#   VIN..1.10. County   City        State ZIP.Code Model.Year Make
# 1 KNDCE3LG3L King     RENTON      WA    98059    2020       KIA
# 2 KNDCE3LG9K King     SEATTLE     WA    98108    2019       KIA
# 3 KNDCC3LG5L King     RENTON      WA    98057    2020       KIA
# 4 1G1FY6S00K Thurston YELM        WA    98597    2019       CHEVROLET
# 5 1N4AZ0CP6F Chelan   LEAVENWORTH WA    98826    2015       NISSAN
# 6 1FADP5CU4F King     SEATTLE     WA    98122    2015       FORD
#   Model         Electric.Vehicle.Type
# 1 NIRO          Battery Electric Vehicle (BEV)
# 2 NIRO ELECTRIC Battery Electric Vehicle (BEV)
# 3 NIRO          Battery Electric Vehicle (BEV)
# 4 BOLT          Battery Electric Vehicle (BEV)
# 5 LEAF          Battery Electric Vehicle (BEV)
# 6 C-MAX ENERGI  Plug-in Hybrid Electric Vehicle (PHEV)
#   Clean.Alternative.Fuel.Vehicle..CAFV..Eligibility Electric.Range Base.MSRP
# 1 Clean Alternative Fuel Vehicle Eligible           239                0
# ...

# %%
head(Electric_Vehicle_Growth_2)
# Out:
#   VIN..1.10. County   City        State ZIP.Code Model.Year Make
# 1 KNDCE3LG3L King     RENTON      WA    98059    2020       KIA
# 2 KNDCE3LG9K King     SEATTLE     WA    98108    2019       KIA
# 3 KNDCC3LG5L King     RENTON      WA    98057    2020       KIA
# 4 1G1FY6S00K Thurston YELM        WA    98597    2019       CHEVROLET
# 5 1N4AZ0CP6F Chelan   LEAVENWORTH WA    98826    2015       NISSAN
# 6 1FADP5CU4F King     SEATTLE     WA    98122    2015       FORD
#   Model         Electric.Vehicle.Type
# 1 NIRO          Battery Electric Vehicle (BEV)
# 2 NIRO ELECTRIC Battery Electric Vehicle (BEV)
# 3 NIRO          Battery Electric Vehicle (BEV)
# 4 BOLT          Battery Electric Vehicle (BEV)
# 5 LEAF          Battery Electric Vehicle (BEV)
# 6 C-MAX ENERGI  Plug-in Hybrid Electric Vehicle (PHEV)
#   Clean.Alternative.Fuel.Vehicle..CAFV..Eligibility Electric.Range Base.MSRP
# 1 Clean Alternative Fuel Vehicle Eligible           239                0
# ...

# %%
head(Electric_Vehicle_Population)
# Out:
#   Car                   Style                 Range              Transmission
# 1 Tata Nexon EV         Compact SUV           312 Km/Full Charge Automatic
# 2 Tata Tigor EV         Subcompact Sedan      306 Km/Full Charge Automatic
# 3 Tata Nexon EV Max     Compact SUV           437 Km/Full Charge Automatic
# 4 MG ZS EV              Compact SUV           419 Km/Full Charge Automatic
# 5 Hyundai Kona Electric Compact SUV           452 Km/Full Charge Automatic
# 6 Jaguar I-Pace         Premium Midsize Sedan 470 Km/Full Charge Automatic
#   VehicleType PriceRange        Capacity  BootSpace BaseModel
# 1 Electric    ₹ 13.99 - 17.4 L  5 Seater  350 L     XM
# 2 Electric    ₹ 12.49 - 13.64 L 5 Seater  316 L     XE
# 3 Electric    ₹ 17.74 - 19.24 L 5 Seater  350 L     XZ Plus 3.3 kW
# 4 Electric    ₹ 21.99 - 25.88 L 5 Seater  448 L     Excite
# 5 Electric    ₹ 23.79 - 23.98 L 5 Seater  na        Premium Dual Tone
# 6 Electric    ₹ 1.06 - 1.12 Cr  5 Seater  656 L     S
#   TopModel
# ...

# %% [markdown]
# 1. I want to further analyse the following variables for the Electric_Vehicle_Growth_1 dataset: Model, Electric.Vehicle.Type, Clean.Alternative.Fuel.Vehicle.Eligibility, Electric.Range.
#
# 2. I also want to further analyse the following variables for the Electric_Vehicle_Population dataset:Car, Range, VehicleType,and PriceRange.

# %%
trimmed_df <-Electric_Vehicle_Growth_1 %>% 
select(Model.Year, Make, Model, Electric.Vehicle.Type, Clean.Alternative.Fuel.Vehicle..CAFV..Eligibility, Electric.Range)

# %%
trimmed_df2<- Electric_Vehicle_Population %>%
select(Car, Range, VehicleType, PriceRange)

# %%
head(trimmed_df)

head(trimmed_df2)
# Out:
#   Model.Year Make      Model         Electric.Vehicle.Type
# 1 2020       KIA       NIRO          Battery Electric Vehicle (BEV)
# 2 2019       KIA       NIRO ELECTRIC Battery Electric Vehicle (BEV)
# 3 2020       KIA       NIRO          Battery Electric Vehicle (BEV)
# 4 2019       CHEVROLET BOLT          Battery Electric Vehicle (BEV)
# 5 2015       NISSAN    LEAF          Battery Electric Vehicle (BEV)
# 6 2015       FORD      C-MAX ENERGI  Plug-in Hybrid Electric Vehicle (PHEV)
#   Clean.Alternative.Fuel.Vehicle..CAFV..Eligibility Electric.Range
# 1 Clean Alternative Fuel Vehicle Eligible           239
# 2 Clean Alternative Fuel Vehicle Eligible           239
# 3 Clean Alternative Fuel Vehicle Eligible           239
# 4 Clean Alternative Fuel Vehicle Eligible           238
# 5 Clean Alternative Fuel Vehicle Eligible            84
# 6 Not eligible due to low battery range              19
#   Car                   Range              VehicleType PriceRange
# ...

# %%
colnames(trimmed_df)

colnames(trimmed_df2)
# Out:
# [1] "Model.Year"
# [2] "Make"
# [3] "Model"
# [4] "Electric.Vehicle.Type"
# [5] "Clean.Alternative.Fuel.Vehicle..CAFV..Eligibility"
# [6] "Electric.Range"
# [1] "Car"         "Range"       "VehicleType" "PriceRange"

# %%
n_distinct(Electric_Vehicle_Growth_1$Id)

n_distinct(Electric_Vehicle_Population$Id)
# Out:
# [1] 0
# [1] 0

# %%
ggplot(data = Electric_Vehicle_Growth_1)+ 
geom_point(mapping = aes(x = Electric.Vehicle.Type, y = Electric.Range))+ 
geom_smooth(mapping = aes(x = Electric.Vehicle.Type, y = Electric.Range))+
labs(title="Electrical Vehicle Type vs. Electric Range")
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'

# %%
ggplot(Electric_Vehicle_Population, aes(x = PriceRange, y = Range, color = Car)) +
  geom_point()

# %%
ggplot(data = Electric_Vehicle_Growth_1)+ 
geom_col(mapping = aes(x = Electric.Vehicle.Type, y = Electric.Range))+
labs(title="Electrical Vehicle Type vs. Electric Range")
